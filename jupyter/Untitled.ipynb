# %%
import pandas as pd
import vaex as vx
import dask.dataframe as dd

# %%
df = pd.read_csv("../data/bitstampUSD_1-min_data_2012-01-01_to_2019-03-13.csv")

# %%
df
# Out:
#           Timestamp     Open     High      Low    Close  Volume_(BTC)  \
# 0        1325317920     4.39     4.39     4.39     4.39      0.455581
# 1        1325317980      NaN      NaN      NaN      NaN           NaN
# 2        1325318040      NaN      NaN      NaN      NaN           NaN
# 3        1325318100      NaN      NaN      NaN      NaN           NaN
# 4        1325318160      NaN      NaN      NaN      NaN           NaN
# 5        1325318220      NaN      NaN      NaN      NaN           NaN
# 6        1325318280      NaN      NaN      NaN      NaN           NaN
# 7        1325318340      NaN      NaN      NaN      NaN           NaN
# 8        1325318400      NaN      NaN      NaN      NaN           NaN
# 9        1325318460      NaN      NaN      NaN      NaN           NaN
# 10       1325318520      NaN      NaN      NaN      NaN           NaN
# 11       1325318580      NaN      NaN      NaN      NaN           NaN
# ...

# %%
from datetime import datetime

# %%
df.loc[:, "datetime"]=pd.to_datetime(df["Timestamp"], unit='s')

# %%
ohlc_dict = {
    'Open':'first',
    'High':'max',
    'Low':'min',
    'Close':'last',
    'Volume_(Currency)':'sum'
    }

# %%
df_d = df.set_index('datetime')

# %%
df_accept = df_d[datetime(2013, 8, 1):]

# %%
ddf = dd.from_pandas(df_accept)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-3977fb16e895> in <module>()
# ----> 1 ddf = dd.from_pandas(df_accept)
#
# ~/.pyenv/versions/3.6.0/lib/python3.6/site-packages/dask/dataframe/io/io.py in from_pandas(data, npartitions, chunksize, sort, name)
#     170
#     171     if ((npartitions is None) == (chunksize is None)):
# --> 172         raise ValueError('Exactly one of npartitions and chunksize must be specified.')
#     173
#     174     nrows = len(data)
#
# ValueError: Exactly one of npartitions and chunksize must be specified.

# %%
vf.T
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-4234d8e40faf> in <module>()
# ----> 1 vf.T
#
# ~/.pyenv/versions/3.6.0/lib/python3.6/site-packages/vaex/dataframe.py in __getattr__(self, name)
#     211             return self.__hidden__[name].__get__(self)
#     212         else:
# --> 213             return object.__getattribute__(self, name)
#     214
#     215     @property
#
# AttributeError: 'DataFrameArrays' object has no attribute 'T'

# %%
def resample_and_join(df, base_bins, *args):
    for a in args:

# %%
def data_set(df, length, how, num, base_bin='60min'):
    X = []
    df_resampled = df.resample(base_bin, how=how)
    for n in len(df_resampled):
        x_base = df_resampled.iloc[n:n+60]
        min_date = x_base.idxmin()
        max_date = x_base.idxmax()
        unit = df[min_date:max_date]
        x.append(x_base)
        x.append(unit.resample('1min', how=how))
        x.append(unit.resample('5min', how=how))
        x.append(unit.resmaple('15min', how=how))
